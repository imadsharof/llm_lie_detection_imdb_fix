# %% [markdown]
# # Phase 2: Data Efficiency and Scalability (RQ4)
#
# **Objective**: Determine how the amount of training data affects the performance of black-box and white-box lie detection methods, and which approach demonstrates greater sample efficiency across varying dataset sizes.
#
# The experiment evaluates metrics on varying training sizes (100, 200, 500, 1K, 2K, up to 5K) all balanced equally (50/50 Truths/Lies) while testing firmly on a hold-out test set of 1000 pairs. We investigate 10 large datasets capable of scaling this test.

# %% [markdown]
# # Colab & Environment Setup

# %%
# !git clone https://github.com/GeorgeVasile04/llm_lie_detection_black_vs_white_box.git
# Out:
# Cloning into 'llm_lie_detection_black_vs_white_box'...
# remote: Enumerating objects: 1066, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1066 (delta 15), reused 21 (delta 15), pack-reused 1044 (from 1)
# Receiving objects: 100% (1066/1066), 71.43 MiB | 26.72 MiB/s, done.
# Resolving deltas: 100% (514/514), done.

# %%
try:
    import google.colab
    IN_COLAB = True
    print("Running in Google Colab. Installing dependencies...")
    get_ipython().system('pip install -q transformers accelerate datasets scikit-learn pandas')

    from google.colab import drive
    drive.mount('/content/drive')

    import sys, os

    # Check possible paths for the root repo dir
    possible_paths = [
        '/content/drive/MyDrive/llm_lie_detection_black_vs_white_box/Black_vs_White_Lie_Detection/Data_Efficiency_BB_WB',
        '/content/llm_lie_detection_black_vs_white_box/Black_vs_White_Lie_Detection/Data_Efficiency_BB_WB',
        os.path.join(os.getcwd(), 'Black_vs_White_Lie_Detection', 'Data_Efficiency_BB_WB'),
        os.getcwd()
    ]

    base_proj_path = None
    for path in possible_paths:
        if os.path.exists(path) and os.path.exists(os.path.join(path, 'load_data_efficiency.py')):
            base_proj_path = path
            break

    if base_proj_path:
        os.chdir(base_proj_path)
        print(f"✅ Changed working directory to: {base_proj_path}")
    else:
        print("⚠️ Could not find project directory automatically. Falling back to simple repo clone approach.")
        # If drive sync fails or the folder isn't found, auto-clone the repo as a fallback!
        get_ipython().system('git clone https://github.com/GeorgeVasile04/llm_lie_detection_black_vs_white_box.git /content/repo')
        base_proj_path = '/content/repo/Black_vs_White_Lie_Detection/Data_Efficiency_BB_WB'
        os.chdir(base_proj_path)
        print(f"✅ Downloaded fresh copy from GitHub and moved to: {base_proj_path}")

    # Add Aligned_Comparison_BB_WB to sys path so we can import unmodified core utils
    aligned_path = os.path.abspath(os.path.join(base_proj_path, '..', 'Aligned_Comparison_BB_WB'))
    sys.path.insert(0, aligned_path)
    sys.path.insert(0, base_proj_path)
    # Also add the very root repo to path to ensure repeng loads correctly
    repo_root = os.path.abspath(os.path.join(base_proj_path, '..', '..'))
    sys.path.insert(0, repo_root)

    print(f"✅ Executing in: {os.getcwd()}")

    from huggingface_hub import login
    from google.colab import userdata
    hf_token = userdata.get('HF_TOKEN')
    if hf_token: login(token=hf_token)

except ImportError:
    IN_COLAB = False
    import sys, os
    # Local fallback
    current_dir = os.getcwd()
    aligned_path = os.path.abspath(os.path.join(current_dir, '..', 'Aligned_Comparison_BB_WB'))
    if aligned_path not in sys.path:
        sys.path.insert(0, aligned_path)
    if current_dir not in sys.path:
        sys.path.insert(0, current_dir)
# Out:
# Running in Google Colab. Installing dependencies...
# Mounted at /content/drive
# ✅ Changed working directory to: /content/llm_lie_detection_black_vs_white_box/Black_vs_White_Lie_Detection/Data_Efficiency_BB_WB
# ✅ Executing in: /content/llm_lie_detection_black_vs_white_box/Black_vs_White_Lie_Detection/Data_Efficiency_BB_WB

# %% [markdown]
# # Imports & Configuration

# %%
# --- Configure PyTorch CUDA allocator to avoid fragmentation on long extraction runs ---
# Must be set BEFORE the first CUDA op (i.e. before model.to('cuda')).
# `expandable_segments:True` lets the allocator grow/shrink allocations without
# fragmenting the cache, which is critical for 50k-sample extractions.
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import torch
import numpy as np
import pandas as pd
import time
from tqdm.auto import tqdm
import sys

# Add path for White Box models directly
current_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(current_dir, '..', '..')))

if current_dir not in sys.path:
    sys.path.insert(0, current_dir)

# Import unmodified feature extractors from Aligned Comparison
from Black_vs_White_Lie_Detection.Aligned_Comparison_BB_WB.wb_activations import load_model, get_activations_for_dataset
from Black_vs_White_Lie_Detection.Aligned_Comparison_BB_WB.bb_logprobs import compute_bb_features_for_dataset

# Import custom Efficiency specific loaders directly matching previous experiment structure (but avoiding A/B complexity)
from load_data_efficiency import load_dataset_efficiency, robust_get_activations
from Black_vs_White_Lie_Detection.Class_Balance_Impact_BB_WB.wb_probes_imbalance import train_wb_probes_imbalance
from Black_vs_White_Lie_Detection.Class_Balance_Impact_BB_WB.bb_classifier_imbalance import train_bb_classifier_imbalance

MODEL_NAME = "meta-llama/Llama-2-7b-chat-hf"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %% [markdown]
# # 1. Create Datasets (Efficiency Phase 2)

# %%
# We target the 10 datasets that successfully scaled to ~3,000+ balanced unique questions (or close).
DATASETS_CONFIG = [
    "commonsense_qa",
    "race",
    "arc_easy",
    "open_book_qa",
    "boolq",
    "rte",
    "imdb",
    "amazon_polarity",
    "ag_news",
    "dbpedia_14"
]

dataset_dict = {}
N_TEST = 1000

print("Pulling maximizing Class Distribution arrays...\n")
for ds_name in DATASETS_CONFIG:
    print(f"--- Processing {ds_name} ---")

    # Load 1:1 completely balanced sets (Train Split / Max)
    df_raw = load_dataset_efficiency(ds_name, split='all', random_seed=42)

    if len(df_raw) > 0:
        total_questions = len(df_raw) // 2
        print(f"Loaded {total_questions} balanced pairs (total {len(df_raw)} logs).")

        # Keep everything sorted perfectly Truth,False pairs
        # Calculate exactly the limit we can afford. Max 5k trains, min 1k for test.
        # So we want up to 6000 lines (3000 pairs). Let's secure 1000 lines for validation (500 pairs)
        max_possible_pairs = min(3000, total_questions)

        if max_possible_pairs < 500: # Below bare minimum metric capabilities
            print(f"⚠️ {ds_name} lacks enough data (<500 pairs). Skipping.")
            continue

        # Extract limits:
        n_val_pairs = 500
        n_train_pairs = max_possible_pairs - n_val_pairs

        total_val_samples = n_val_pairs * 2
        total_train_samples = n_train_pairs * 2

        # 0 : train_limit => Train (e.g., 5000 records)
        # train_limit : max => Test (e.g., 1000 records)
        df_train_full = df_raw.iloc[:total_train_samples].reset_index(drop=True)
        df_val_full = df_raw.iloc[total_train_samples:total_train_samples+total_val_samples].reset_index(drop=True)

        dataset_dict[ds_name] = {
            "train_full": df_train_full,
            "validation": df_val_full
        }

        print(f"✅ {ds_name} Mapped -> Train Capability: {len(df_train_full)} | Held-Out Test: {len(df_val_full)}\n")
    else:
        print(f"⚠️ {ds_name} failed to load properly. Skipping.")

DATASETS = list(dataset_dict.keys())
# Out:
# Pulling maximizing Class Distribution arrays...
#
# --- Processing commonsense_qa ---
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/160k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/151k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/1140 [00:00<?, ? examples/s]
# Loaded 10962 balanced pairs (total 21924 logs).
# ✅ commonsense_qa Mapped -> Train Capability: 5000 | Held-Out Test: 1000
#
# --- Processing race ---
# README.md: 0.00B [00:00, ?B/s]
# all/test-00000-of-00001.parquet:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# all/train-00000-of-00001.parquet:   0%|          | 0.00/37.4M [00:00<?, ?B/s]
# all/validation-00000-of-00001.parquet:   0%|          | 0.00/2.05M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/4887 [00:00<?, ? examples/s]
# Loaded 26524 balanced pairs (total 53048 logs).
# ...

# %%
# --- NEW EXPERIMENT: SCALING LR-G UP TO 50K SAMPLES ---

NEW_DATASETS_CONFIG = {
    "boolq": 20000, # 17854
    "imdb": 10000, # I set the limit to 10k for imdb because it provoqs extreme GPU memory issues.
    "commonsense_qa": 20000,
    "race": 50000,
    "amazon_polarity": 50000,
    "ag_news": 50000,
    "dbpedia_14": 50000,
    "open_book_qa": 10000, # 9914
}

dataset_dict_large = {}
N_VAL_PAIRS = 500  # 1000 logic samples for validation (exactly as step 1)

print("Pulling maximizing Class Distribution arrays for LARGE scale experiment...\n")
for ds_name, target_size in NEW_DATASETS_CONFIG.items():
    print(f"--- Processing {ds_name} (Target Train: {target_size}) ---")

    # Load 1:1 completely balanced sets
    df_raw = load_dataset_efficiency(ds_name, split='all', random_seed=42)

    if len(df_raw) > 0:
        total_questions = len(df_raw) // 2

        # Max pair target plus the 500 val holdouts
        target_train_pairs = target_size // 2

        # We can take up to the maximum available minus the val holdout
        max_possible_pairs = total_questions - N_VAL_PAIRS

        if max_possible_pairs < target_train_pairs:
            print(f"⚠️ {ds_name} naturally runs out of data at {max_possible_pairs*2} instead of {target_size}. Using max.")
            actual_train_pairs = max_possible_pairs
        else:
            actual_train_pairs = target_train_pairs

        if actual_train_pairs < 500: # Below bare minimum metric capabilities
            print(f"⚠️ {ds_name} lacks enough data. Skipping.")
            continue

        # Limits
        total_val_samples = N_VAL_PAIRS * 2
        total_train_samples = actual_train_pairs * 2

        df_train_large = df_raw.iloc[:total_train_samples].reset_index(drop=True)
        df_val_large = df_raw.iloc[total_train_samples:total_train_samples+total_val_samples].reset_index(drop=True)

        dataset_dict_large[ds_name] = {
            "train_full": df_train_large,
            "validation": df_val_large
        }

        print(f"✅ {ds_name} Mapped -> Train Capability: {len(df_train_large)} | Held-Out Test: {len(df_val_large)}\n")
    else:
        print(f"⚠️ {ds_name} failed to load properly. Skipping.")

LARGE_DATASETS = list(dataset_dict_large.keys())
# Out:
# Pulling maximizing Class Distribution arrays for LARGE scale experiment...
#
# --- Processing boolq (Target Train: 20000) ---
# README.md: 0.00B [00:00, ?B/s]
# boolq/train-00000-of-00001.parquet:   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# boolq/validation-00000-of-00001.parquet:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# boolq/test-00000-of-00001.parquet:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/3245 [00:00<?, ? examples/s]
# ⚠️ boolq naturally runs out of data at 17854 instead of 20000. Using max.
# ✅ boolq Mapped -> Train Capability: 17854 | Held-Out Test: 1000
#
# --- Processing imdb (Target Train: 10000) ---
# README.md: 0.00B [00:00, ?B/s]
# plain_text/train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# plain_text/test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# plain_text/unsupervised-00000-of-00001.p(…):   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # 2. Load the model

# %%
import gc
print("Loading Model...")
model, tokenizer = load_model(MODEL_NAME, device=DEVICE)
# Out:
# Loading Model...
# Loading model: meta-llama/Llama-2-7b-chat-hf...
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %% [markdown]
# # 3. Extract activations vectors for white box

# %%
WB_BATCH_SIZE = 74 # White Box needs all hidden states, limiting memory

# --- POST-FIX dlk.py: ré-extraction ciblée ---
# Après le fix du shuffle déterministe (DLK_SHUFFLE_SEED dans dlk.py), seules
# les wb_features de imdb et amazon_polarity sont périmées (chemin >20k lignes).
# On préserve toute entrée déjà calculée dans cette session de kernel.
TARGET_RE_EXTRACT = ["imdb", "amazon_polarity"]
try:
    wb_features
except NameError:
    wb_features = {}

datasets_to_run = [d for d in DATASETS if d in TARGET_RE_EXTRACT]
print(f"WB extraction ciblée sur: {datasets_to_run}")
print(f"WB features déjà en RAM (préservées): {[d for d in DATASETS if d in wb_features and d not in TARGET_RE_EXTRACT]}")

for ds_name in tqdm(datasets_to_run, desc="Dataset WB Extraction"):
    # Dynamically lower batch size heavily for datasets with long text paragraphs!
    if ds_name == "race":
        current_batch_size = 32
    elif ds_name == "imdb":
        current_batch_size = 32
    else:
        current_batch_size = WB_BATCH_SIZE

    df_train = dataset_dict[ds_name]["train_full"]
    df_val = dataset_dict[ds_name]["validation"]

    act_train_full = get_activations_for_dataset(df_train, model, tokenizer, device=DEVICE, batch_size=current_batch_size, show_progress=True)
    act_val_full = get_activations_for_dataset(df_val, model, tokenizer, device=DEVICE, batch_size=current_batch_size, show_progress=True)

    wb_features[ds_name] = {"train_full": act_train_full, "validation": act_val_full}
    print(f"✅ {ds_name} WB -> Train inferences: {len(act_train_full)} | Val inferences: {len(act_val_full)} physically computed.")

    # Clear RAM
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# # 3-B. Extract large-scale Activation Vectors for LR-G

# %%
import gc
import torch

WB_BATCH_SIZE = 80 # Same standard batch size

# --- POST-FIX dlk.py: ré-extraction ciblée (large scale) ---
TARGET_RE_EXTRACT_LARGE = ["imdb", "amazon_polarity"]
try:
    wb_features_large
except NameError:
    wb_features_large = {}

datasets_to_run_large = [d for d in LARGE_DATASETS if d in TARGET_RE_EXTRACT_LARGE]
print(f"WB large-scale extraction ciblée sur: {datasets_to_run_large}")
print(f"WB large déjà en RAM (préservées): {[d for d in LARGE_DATASETS if d in wb_features_large and d not in TARGET_RE_EXTRACT_LARGE]}")

for ds_name in datasets_to_run_large:
    # Base starting batch sizes adapted to datasets
    if ds_name == "race":
        base_batch_size = 40
    elif ds_name == "imdb" or ds_name == "boolq":
        base_batch_size = 32
    else:
        base_batch_size = WB_BATCH_SIZE

    df_train_large = dataset_dict_large[ds_name]["train_full"]
    df_val_large = dataset_dict_large[ds_name]["validation"]

    target_train = len(df_train_large)
    target_val = len(df_val_large)

    act_train_full = robust_get_activations(
        df_train_large, model, tokenizer, DEVICE, base_batch_size, desc=f"{ds_name} Train", target_size=target_train
    )

    act_val_full = robust_get_activations(
        df_val_large, model, tokenizer, DEVICE, base_batch_size, desc=f"{ds_name} Val", target_size=target_val
    )

    wb_features_large[ds_name] = {"train_full": act_train_full, "validation": act_val_full}
    print(f"✅ {ds_name} LARGE WB -> Train inferences: {len(act_train_full)} | Val inferences: {len(act_val_full)} physically computed.")

    # Clear RAM between datasets
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# # Save the vector states from step 3

# %%
# Code to save WB features to disk has been removed as requested.
# wb_features is kept directly in memory.
print("✅ White-Box features are kept in memory (RAM). Skipping disk save.")

# %% [markdown]
# # 4. Compute logprobs for black box

# %%
import os
import gc
import pickle
import numpy as np
from tqdm import tqdm
import torch

try:
    probe_base = "../../Black_Box_Lie_Detection/results/probes_groups"
    no_lie_indices = np.load(os.path.join(probe_base, "no_lie_indices.npy"))
    lie_indices = np.load(os.path.join(probe_base, "lie_indices.npy"))
    knowable_indices = np.load(os.path.join(probe_base, "knowable_indices.npy"))
    PAPER_PROBE_INDICES = np.concatenate([no_lie_indices, lie_indices, knowable_indices])
    print(f"✅ Loaded {len(PAPER_PROBE_INDICES)} elicitation questions")
except FileNotFoundError:
    PAPER_PROBE_INDICES = None

bb_features = {}
checkpoint_dir = 'outputs'
os.makedirs(checkpoint_dir, exist_ok=True)

# --- POST-FIX dlk.py: ré-extraction BB ciblée ---
# Les pkl disque pour imdb et amazon_polarity sont périmés (prompts changés).
# Les autres datasets gardent leur pkl existant — on les recharge sans recalculer.
TARGET_BB_RE_EXTRACT = ["imdb", "amazon_polarity"]
print(f"BB extraction ciblée sur: {TARGET_BB_RE_EXTRACT}")
print(f"Autres datasets: rechargement depuis le cache disque dans '{checkpoint_dir}/'")

for ds_name in tqdm(DATASETS, desc="Dataset BB Extraction"):
    file_path = os.path.join(checkpoint_dir, f"{ds_name}_bb_features_efficiency.pkl")

    if ds_name not in TARGET_BB_RE_EXTRACT and os.path.exists(file_path):
        with open(file_path, 'rb') as f:
            bb_features[ds_name] = pickle.load(f)
        print(f"⏩ {ds_name} BB -> rechargé depuis {file_path} (pas de recalcul).")
        continue

    df_train = dataset_dict[ds_name]["train_full"]
    df_val = dataset_dict[ds_name]["validation"]

    current_bb_batch = 48

    # 🌟 THIS SETS THE SPEED AND SAVES MEMORY FOR THE SPECIFIC DATASET! 🌟
    current_probe_batch = 24 if ds_name == "imdb" else 48

    bb_train_full = compute_bb_features_for_dataset(
        df_train, model, tokenizer, device=DEVICE, batch_size=current_bb_batch, probe_indices=PAPER_PROBE_INDICES, show_progress=True, probe_batch_size=current_probe_batch
    )
    bb_val_full = compute_bb_features_for_dataset(
        df_val, model, tokenizer, device=DEVICE, batch_size=current_bb_batch, probe_indices=PAPER_PROBE_INDICES, show_progress=True, probe_batch_size=current_probe_batch
    )

    def unpack_bb(bb_dict):
        X, Y = [], []
        for r in bb_dict:
            if "bb_features" in r and r["bb_features"]:
                X.append([p["score"] for p in r["bb_features"]])
                Y.append(r["label"])
        return np.array(X), np.array(Y)

    bb_ds_features = {
        "train_full": unpack_bb(bb_train_full),
        "validation": unpack_bb(bb_val_full)
    }

    bb_features[ds_name] = bb_ds_features

    # Save progressively after each dataset INTO ITS OWN FILE
    with open(file_path, 'wb') as f:
        pickle.dump(bb_ds_features, f)

    print(f"✅ Saved progressive checkpoint for {ds_name} at {file_path}")

    # Clean GPU and RAM
    torch.cuda.empty_cache()
    gc.collect()

print(f"✅ Successfully finished and saved all BB features separately to {checkpoint_dir}")

# %% [markdown]
# # Start from here once step 4 is saved

# %%
import os
import pickle
import glob

# Ensure this points to the right path depending on if you are local or in colab
checkpoint_dir = 'outputs'

# wb_features is already in memory from Step 3.
# We only need to load the Black-Box features from disk.

bb_features = {}
bb_files = glob.glob(os.path.join(checkpoint_dir, "*_bb_features_efficiency.pkl"))

print(f"Found {len(bb_files)} Black-Box feature files.")

for file_path in bb_files:
    ds_name = os.path.basename(file_path).replace("_bb_features_efficiency.pkl", "")
    with open(file_path, 'rb') as f:
        bb_features[ds_name] = pickle.load(f)
    print(f"✅ Loaded BB features for {ds_name}")

# We take the intersection to ensure the training loop doesn't crash
# if a dataset is missing from either wb_features or bb_features
DATASETS = [ds for ds in wb_features.keys() if ds in bb_features.keys()]
print(f"\n✅ Ready to evaluate on exactly {len(DATASETS)} datasets: {DATASETS}")
# Out:
# Found 10 Black-Box feature files.
# ✅ Loaded BB features for open_book_qa
# ✅ Loaded BB features for rte
# ✅ Loaded BB features for race
# ✅ Loaded BB features for boolq
# ✅ Loaded BB features for imdb
# ✅ Loaded BB features for arc_easy
# ✅ Loaded BB features for amazon_polarity
# ✅ Loaded BB features for commonsense_qa
# ✅ Loaded BB features for dbpedia_14
# ✅ Loaded BB features for ag_news
#
# ✅ Ready to evaluate on exactly 10 datasets: ['commonsense_qa', 'race', 'arc_easy', 'open_book_qa', 'boolq', 'rte', 'imdb', 'amazon_polarity', 'ag_news', 'dbpedia_14']

# %% [markdown]
# # 5. Train Classifiers at Various Data Scales
#
# We perform the training loop for sizes N = [100, 200, 500, 1000, 2000, 5000]. If the dataset doesn't have enough lines for a specific N, it takes the `max_avail` length. We then test strictly on the unchanged held-out 1000 test set.

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, average_precision_score, precision_recall_curve
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import os
import sys
import gc
from contextlib import redirect_stdout, redirect_stderr

# Import CV function from imbalance suite
from Black_vs_White_Lie_Detection.Class_Balance_Impact_BB_WB.wb_probes_imbalance import select_best_layer_cv, train_wb_probes_imbalance
from Black_vs_White_Lie_Detection.Class_Balance_Impact_BB_WB.bb_classifier_imbalance import train_bb_classifier_imbalance


def best_recall_at_precision(y_true, y_scores, target_precision=0.90):
    if len(np.unique(y_true)) < 2:
        return 0.0
    precisions, recalls, thresholds = precision_recall_curve(y_true, y_scores)
    valid_idx = np.where(precisions >= target_precision)[0]
    if len(valid_idx) == 0:
        return 0.0
    return np.max(recalls[valid_idx])

# Include ALL 32 layers for pure CV
LAYER_LIST_CV = list(range(1, 33))
WB_METHODS = ["lr", "dim", "lat", "ccs", "lda", "pca", "pca-g", "lr-g"]
TRAIN_SIZES = [100, 200, 500, 1000, 2000, 5000]

all_results = []
os.makedirs("outputs", exist_ok=True)

for ds_name in DATASETS:
    w_tr_full = wb_features[ds_name]["train_full"]
    w_v = wb_features[ds_name]["validation"]

    # BB features
    b_tr_full_X = bb_features[ds_name]["train_full"][0]
    b_tr_full_Y = bb_features[ds_name]["train_full"][1]
    X_val_bb, y_val_bb = bb_features[ds_name]["validation"]

    max_train_avail = len(w_tr_full)
    print(f"\n--- Evaluating {ds_name} on Data Efficiency (Max Avail: {max_train_avail}) ---")

    def calculate_full_metrics(probs_or_logits):
        auc = roc_auc_score(y_val_bb, probs_or_logits) if len(np.unique(y_val_bb)) > 1 else 0.5
        map_score = average_precision_score(y_val_bb, probs_or_logits) if len(np.unique(y_val_bb)) > 1 else 0.5
        brp_90 = best_recall_at_precision(y_val_bb, probs_or_logits, target_precision=0.90)
        return {'AUC': auc, 'MAP': map_score, 'BRP_90': brp_90}

    for size_target in TRAIN_SIZES:
        # We clip training size if max_train_avail < size_target
        actual_size = min(size_target, max_train_avail)

        # Slice Train Arrays
        w_tr_chunk = w_tr_full[:actual_size]
        X_train_bb_chunk = b_tr_full_X[:actual_size]
        y_train_bb_chunk = b_tr_full_Y[:actual_size]

        pbar = tqdm(total=(1 + len(WB_METHODS)), desc=f"{ds_name} (N={size_target})")

        # 1. Train and eval Black Box
        pbar.set_description(f"{ds_name} (N={size_target}) - BB")
        with open(os.devnull, 'w') as f, redirect_stdout(f), redirect_stderr(f):
            bb_model, bb_met_full = train_bb_classifier_imbalance(X_train_bb_chunk, X_val_bb, y_train_bb_chunk, y_val_bb, verbose=False)

        bb_met = calculate_full_metrics(bb_met_full["probs"])
        all_results.append({
            "Dataset": ds_name, "Method": "Black Box", "Algorithm": "BB",
            "Training Size": size_target, "Actual Size Trained": actual_size, "Layer": "N/A",
            "AUC": bb_met["AUC"], "MAP": bb_met["MAP"], "BRP_90": bb_met["BRP_90"]
        })
        pbar.update(1)

        # 2. Train and eval White Box models via CV Layer Selection
        for method in WB_METHODS:
            pbar.set_description(f"{ds_name} (N={size_target}) - WB {method.upper()}")
            best_layer = select_best_layer_cv(w_tr_chunk, layer_list=LAYER_LIST_CV, method=method, verbose=False)

            with open(os.devnull, 'w') as f, redirect_stdout(f), redirect_stderr(f):
                _, wb_met = train_wb_probes_imbalance(w_tr_chunk, eval_data=w_v, layer_list=[best_layer], method=method, verbose=False)

            if best_layer in wb_met:
                mA = calculate_full_metrics(wb_met[best_layer]["logits"])
                all_results.append({
                    "Dataset": ds_name, "Method": "White Box", "Algorithm": method.upper(),
                    "Training Size": size_target, "Actual Size Trained": actual_size, "Layer": best_layer,
                    "AUC": mA["AUC"], "MAP": mA["MAP"], "BRP_90": mA["BRP_90"]
                })

            pbar.update(1)
            gc.collect()

        pbar.set_description(f"{ds_name} (N={size_target}) - Done")
        pbar.close()

    # ====== SAVE PROGRESS AFTER EACH DATASET COMPLETES ======
    intermediate_df = pd.DataFrame(all_results)
    intermediate_df.to_csv("outputs/data_efficiency_metrics_CV_V2.csv", index=False)
    print(f"💾 Checkpoint: Saved {len(intermediate_df)} total rows so far to outputs/data_efficiency_metrics_CV_V2.csv")

final_df = pd.DataFrame(all_results)
print("\n✅ All datasets finished! Final results saved cleanly to outputs/data_efficiency_metrics_CV_V2.csv")
# Out:
# --- Evaluating commonsense_qa on Data Efficiency (Max Avail: 5000) ---
# ...
# commonsense_qa (N=5000):   0%|          | 0/9 [00:00<?, ?it/s]
# ...
# 💾 Checkpoint: Saved 54 total rows so far to outputs/data_efficiency_metrics_CV_V2.csv
#
# --- Evaluating race on Data Efficiency (Max Avail: 5000) ---
# ...
# race (N=5000):   0%|          | 0/9 [00:00<?, ?it/s]
# ...
# 💾 Checkpoint: Saved 108 total rows so far to outputs/data_efficiency_metrics_CV_V2.csv
#
# --- Evaluating arc_easy on Data Efficiency (Max Avail: 4642) ---
# ...
# arc_easy (N=5000):   0%|          | 0/9 [00:00<?, ?it/s]
# ...
# 💾 Checkpoint: Saved 162 total rows so far to outputs/data_efficiency_metrics_CV_V2.csv
#
# --- Evaluating open_book_qa on Data Efficiency (Max Avail: 5000) ---
# ...
# open_book_qa (N=5000):   0%|          | 0/9 [00:00<?, ?it/s]
# ...
# 💾 Checkpoint: Saved 216 total rows so far to outputs/data_efficiency_metrics_CV_V2.csv
#
# --- Evaluating boolq on Data Efficiency (Max Avail: 5000) ---
# ...
# boolq (N=5000):   0%|          | 0/9 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # 5-B. Train LR-G at Large Data Scales

# %%
import pandas as pd
import numpy as np
import os
import gc
from tqdm.auto import tqdm
from contextlib import redirect_stdout, redirect_stderr

# Re-import just in case
from Black_vs_White_Lie_Detection.Class_Balance_Impact_BB_WB.wb_probes_imbalance import select_best_layer_cv, train_wb_probes_imbalance

def best_recall_at_precision(y_true, y_scores, target_precision=0.90):
    from sklearn.metrics import precision_recall_curve
    if len(np.unique(y_true)) < 2:
        return 0.0
    precisions, recalls, thresholds = precision_recall_curve(y_true, y_scores)
    valid_idx = np.where(precisions >= target_precision)[0]
    if len(valid_idx) == 0:
        return 0.0
    return np.max(recalls[valid_idx])

# Load previous BB efficiency results
old_df_path = "outputs/data_efficiency_metrics_CV_V2.csv"
if os.path.exists(old_df_path):
    old_df = pd.read_csv(old_df_path)
    bb_df = old_df[old_df["Algorithm"] == "BB"].copy()
else:
    print(f"⚠️ Warning: Could not find {old_df_path}. BB features won't be appended.")
    bb_df = pd.DataFrame()

LARGE_TRAIN_SIZES = [100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000]
LAYER_LIST_CV = list(range(1, 33))

large_results = []
# Ensure only large datasets processed here, falling back if not found
for ds_name in LARGE_DATASETS:
    if ds_name not in wb_features_large:
        continue

    w_tr_full = wb_features_large[ds_name]["train_full"]
    w_v = wb_features_large[ds_name]["validation"]

    # Extract labels strictly sequentially from the validation embeddings dictionary to ensure perfect alignment
    y_val = np.array([item["label"] for item in w_v])

    def calc_metrics(probs_or_logits):
        from sklearn.metrics import roc_auc_score, average_precision_score
        auc = roc_auc_score(y_val, probs_or_logits) if len(np.unique(y_val)) > 1 else 0.5
        map_score = average_precision_score(y_val, probs_or_logits) if len(np.unique(y_val)) > 1 else 0.5
        brp_90 = best_recall_at_precision(y_val, probs_or_logits, target_precision=0.90)
        return {'AUC': auc, 'MAP': map_score, 'BRP_90': brp_90}

    max_train_avail = len(w_tr_full)
    print(f"\n--- Evaluating {ds_name} LR-G (Max Avail: {max_train_avail}) ---")

    pbar = tqdm(total=len(LARGE_TRAIN_SIZES), desc=f"{ds_name} LR-G")
    for size_target in LARGE_TRAIN_SIZES:
        actual_size = min(size_target, max_train_avail)
        w_tr_chunk = w_tr_full[:actual_size]

        best_layer = select_best_layer_cv(w_tr_chunk, layer_list=LAYER_LIST_CV, method="lr-g", verbose=False)

        with open(os.devnull, 'w') as f, redirect_stdout(f), redirect_stderr(f):
            _, wb_met = train_wb_probes_imbalance(w_tr_chunk, eval_data=w_v, layer_list=[best_layer], method="lr-g", verbose=False)

        if best_layer in wb_met:
            mA = calc_metrics(wb_met[best_layer]["logits"])
            large_results.append({
                "Dataset": ds_name, "Method": "White Box", "Algorithm": "LR-G",
                "Training Size": size_target, "Actual Size Trained": actual_size, "Layer": best_layer,
                "AUC": mA["AUC"], "MAP": mA["MAP"], "BRP_90": mA["BRP_90"]
            })

        pbar.update(1)
        gc.collect()

    pbar.close()

# Combine with Black Box data
large_df = pd.DataFrame(large_results)

if not bb_df.empty:
    # Filter BB elements only from our 9 targeted datasets to keep the plots clean
    bb_df = bb_df[bb_df["Dataset"].isin(LARGE_DATASETS)]
    final_large_df = pd.concat([bb_df, large_df], ignore_axis=True)
else:
    final_large_df = large_df

final_large_df.to_csv("outputs/data_efficiency_LRG_large.csv", index=False)
print(f"\n✅ Large Scale runs complete! Saved cleanly to outputs/data_efficiency_LRG_large.csv")
# Out:
# --- Evaluating boolq LR-G (Max Avail: 17854) ---
# boolq LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating imdb LR-G (Max Avail: 10000) ---
# imdb LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating commonsense_qa LR-G (Max Avail: 20000) ---
# commonsense_qa LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating race LR-G (Max Avail: 50000) ---
# race LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating amazon_polarity LR-G (Max Avail: 50000) ---
# amazon_polarity LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating ag_news LR-G (Max Avail: 50000) ---
# ag_news LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating dbpedia_14 LR-G (Max Avail: 50000) ---
# dbpedia_14 LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# --- Evaluating open_book_qa LR-G (Max Avail: 9914) ---
# open_book_qa LR-G:   0%|          | 0/9 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ...

# %%
# --- RECOVERY CELL ---
# This cell will save the results using the data already calculated in memory.
# It uses the `large_df` or `large_results` that were already computed before the error.

import pandas as pd

# If large_df wasn't successfully created before the error, we re-create it from memory
if 'large_results' in locals() and len(large_results) > 0:
    large_df = pd.DataFrame(large_results)
elif 'large_df' not in locals():
    print("⚠️ Neither large_results nor large_df are found in memory. You might need to rerun the main cell.")

if 'large_df' in locals():
    if 'bb_df' in locals() and not bb_df.empty:
        # Filter BB elements only from our 9 targeted datasets
        bb_df = bb_df[bb_df["Dataset"].isin(LARGE_DATASETS)]
        # FIXED: replace ignore_axis=True with ignore_index=True
        final_large_df = pd.concat([bb_df, large_df], ignore_index=True)
    else:
        final_large_df = large_df

    final_large_df.to_csv("outputs/data_efficiency_LRG_large.csv", index=False)
    print(f"✅ Data recovered and saved successfully to outputs/data_efficiency_LRG_large.csv!")
# Out:
# ✅ Data recovered and saved successfully to outputs/data_efficiency_LRG_large.csv!

# %% [markdown]
# # 6. Visualization: Data Efficiency Curves

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the newly generated V2 CSV
if 'final_df' not in locals() or final_df is None:
    final_df = pd.read_csv("outputs/data_efficiency_metrics_CV_V2.csv")

METRICS = ["AUC", "MAP", "BRP_90"]

sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)

for metric in METRICS:
    plt.figure(figsize=(12, 7))

    # Calculate the mean performance of each algorithm at each Training Size (averaging out the Datasets)
    mean_df = final_df.groupby(['Algorithm', 'Training Size'])[metric].mean().reset_index()

    # Plot 1 curve per Algorithm (Total: 9 curves) on one graph, across x=Training Size
    sns.lineplot(data=mean_df, x="Training Size", y=metric, hue="Algorithm",
                 marker="o", linewidth=3.0, palette="tab10")

    plt.title(f'Mean Data Efficiency Across All Datasets: {metric}', fontsize=16, fontweight='bold')

    # Log scale is vital because jumping from 100 to 5000 is a wide range
    plt.xscale("log")

    # Map exact ticks
    ticks = [100, 200, 500, 1000, 2000, 5000]
    plt.xticks(ticks, [str(t) for t in ticks])
    plt.xlabel("Training Size (Log Scale)", fontsize=14)
    plt.ylabel(f"Mean {metric}", fontsize=14)

    # Move legend safely outside the plot
    plt.legend(title="Algorithm", bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.savefig(f"outputs/mean_efficiency_curve_{metric}_CV_V2.png", dpi=300, bbox_inches='tight')
    plt.show()

print("\n🌟 PHASE 2 EXPERIMENT COMPLETE: MEAN DATA EFFICIENCY CURVES GENERATED. 🌟")
# Out:
# 🌟 PHASE 2 EXPERIMENT COMPLETE: MEAN DATA EFFICIENCY CURVES GENERATED. 🌟

# %% [markdown]
# # 6-B. Visualization: Large-Scale LR-G vs Black-Box Data Efficiency

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load our newly generated Large-Scale output file
try:
    final_large_df = pd.read_csv("outputs/data_efficiency_LRG_large.csv")

    METRICS = ["AUC", "MAP", "BRP_90"]
    sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)

    # Setup subplots: 3 metrics (rows) x 2 algorithms (columns)
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 18), sharey="row")

    # Helper limits
    wb_df = final_large_df[final_large_df["Algorithm"] == "LR-G"]
    bb_df = final_large_df[final_large_df["Algorithm"] == "BB"]

    wb_ticks = [100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000]
    bb_ticks = [100, 200, 500, 1000, 2000, 5000]

    for row_idx, metric in enumerate(METRICS):
        # --- LEFT COLUMN: WHITE BOX (LR-G) ---
        ax_wb = axes[row_idx, 0]
        sns.lineplot(
            data=wb_df,
            x="Actual Size Trained",
            y=metric,
            hue="Dataset",
            ax=ax_wb,
            marker="o",
            linewidth=2.5,
            palette="tab10"
        )
        ax_wb.set_title(f"White Box (LR-G): {metric}", fontsize=14, fontweight='bold')
        ax_wb.set_xscale("log")
        ax_wb.set_xticks(wb_ticks)
        ax_wb.set_xticklabels([str(t) for t in wb_ticks], rotation=45)
        ax_wb.set_xlabel("Actual Size Trained", fontsize=12)
        ax_wb.set_ylabel(metric, fontsize=12)
        ax_wb.grid(True, which="both", ls="--", linewidth=0.5)
        if row_idx == 0:
            ax_wb.legend(title="Dataset", bbox_to_anchor=(0.5, 1.25), loc='lower center', ncol=3) # only need legend once per column ideally
        else:
            ax_wb.get_legend().remove()

        # --- RIGHT COLUMN: BLACK BOX (BB) ---
        ax_bb = axes[row_idx, 1]
        if not bb_df.empty:
            sns.lineplot(
                data=bb_df,
                x="Training Size",
                y=metric,
                hue="Dataset",
                ax=ax_bb,
                marker="o",
                linewidth=2.5,
                palette="tab10"
            )
            ax_bb.set_title(f"Black Box (BB): {metric}", fontsize=14, fontweight='bold')
            ax_bb.set_xscale("log")
            ax_bb.set_xticks(bb_ticks)
            ax_bb.set_xticklabels([str(t) for t in bb_ticks], rotation=45)
            ax_bb.set_xlabel("Training Size", fontsize=12)
            if row_idx == 0:
                 ax_bb.get_legend().remove() # Keep one unified master legend or two, we cleaned WB already
            else:
                 ax_bb.get_legend().remove()
            ax_bb.grid(True, which="both", ls="--", linewidth=0.5)

    # Adjust layout
    plt.tight_layout()
    # Provide room at top for overlapping legend if needed
    plt.subplots_adjust(top=0.92)

    plt.savefig("outputs/large_scale_comparison_LRG_vs_BB.png", dpi=300, bbox_inches='tight')
    plt.show()

    print("\n🌟 PHASE 2.5 EXPERIMENT COMPLETE: LARGE SCALE EFFICIENCY CURVES GENERATED. 🌟")
except Exception as e:
    print(f"Error drawing metrics! Make sure the data extraction runs first: {e}")
# Out:
# 🌟 PHASE 2.5 EXPERIMENT COMPLETE: LARGE SCALE EFFICIENCY CURVES GENERATED. 🌟
